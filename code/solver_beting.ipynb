# %%
import os
import pandas as pd
import re

# Ruta a la carpeta que contiene los archivos
data_folder = "../data/input/daily_dump"

# Crear una lista vacía para almacenar los DataFrames
df_list = []

# Expresión regular para validar la estructura df_games_YYYYMMDD.csv
pattern = re.compile(r'^df_games_\d{8}\.csv$')

# Recorrer los archivos en la carpeta
for file_name in os.listdir(data_folder):
    # Verificar si el archivo cumple con la estructura df_games_YYYYMMDD.csv usando la expresión regular
    if pattern.match(file_name):
        # Extraer la fecha del archivo
        date_str = file_name[9:17]
        year = int(date_str[:4])
        month = int(date_str[4:6])
        day = int(date_str[6:8])
        
        # Filtrar archivos que están entre el 11 y 30 de septiembre de 2024
        if year == 2024 and month == 9 and 11 <= day <= 30:
            # Leer el archivo y agregarlo a la lista
            file_path = os.path.join(data_folder, file_name)
            df = pd.read_csv(file_path)
            df_list.append(df)

# Concatenar todos los DataFrames en uno solo
if df_list:
    df_consolidated = pd.concat(df_list, ignore_index=True)
    
    # Guardar el DataFrame consolidado como un nuevo archivo CSV
    df_consolidated.to_csv(os.path.join(data_folder, "df_games_sep_test.csv"), index=False)
    print("Archivo consolidado guardado como df_games_sep_test.csv")
else:
    print("No se encontraron archivos en el rango de fechas especificado.")
# Out:
# Archivo consolidado guardado como df_games_sep_test.csv

# %%
from src.standarice_data import TenisModelHandler

# Cargar nuevos datos para predicción
df_new = pd.read_csv(os.path.join(data_folder, "df_games_sep_test.csv"), delimiter='|')

# Crear instancia de la clase Preprocessing
preprocessor = TenisModelHandler(df_new, models_path='../models')

# Generar predicciones con el modelo deseado
resultado = preprocessor.predict_values('xgboost')

# Mostrar el DataFrame con las predicciones
print(resultado.head())
# Out:
#                  Location  pl1_bet  pl2_bet        pl1_name       pl1_flag  \
# 0     Szczecin challenger     1.30     3.31      Andreev A.       Bulgaria
# 2     Szczecin challenger     2.81     1.40   Berrettini J.          Italy
# 4     Szczecin challenger     4.27     1.20     Vrbensky M.  CzechRepublic
# 6  Guangzhou 2 challenger     1.22     4.11  Shimabukuro S.          Japan
# 8  Guangzhou 2 challenger     2.41     1.53      Polmans M.      Australia
#
#    pl1_year_pro  pl1_weight  pl1_height pl1_hand  pl1_age  ...      pl2_flag  \
# 0        2015.0        66.0       180.0    right     23.0  ...       Germany
# 2        2012.0        85.0       191.0    right     25.0  ...         Italy
# 4        2016.0        65.0       180.0    right     24.0  ...         Spain
# 6        2015.0        75.0       183.0    right     27.0  ...         China
# 8        2011.0        78.0       188.0    right     27.0  ...  GreatBritain
#
#   pl2_year_pro  pl2_weight  pl2_height  pl2_hand pl2_age  Surface      Date  \
# 0         2011        86.0       193.0      left    29.0     clay  20240911
# 2         2010        90.0       196.0     right    29.0     clay  20240911
# 4         2012        76.0       183.0     right    27.0     clay  20240911
# 6         2006        80.0       185.0     right    35.0     hard  20240911
# 8         2016        69.0       180.0     right    24.0     hard  20240911
#
#    winner_prediction probability
# 0                pl1    0.721002
# 2                pl2    0.561894
# 4                pl2    0.822175
# 6                pl1    0.819615
# 8                pl2    0.669903
#
# [5 rows x 21 columns]
# g:\dev\tennis_bet\code\src\standarice_data.py:397: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[2015. 2012. 2012. ... 2016. 2009. 2020.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.df.update(pl1_df_filled)

# %%
resultado["ActualWinner"] = "pl1"

# %%
resultado["winner_prediction"].value_counts()
# Out:
# winner_prediction
# pl1    408
# pl2    289
# Name: count, dtype: int64

# %%
408 / (408+289)
# Out:
# 0.5853658536585366

# %%
import pandas as pd
import numpy as np
import optuna

# Definir la función objetivo para la optimización
def simulate_betting_strategy(params, resultado, initial_capital=100.0):
    risk_factor, max_daily_bet_fraction, max_bet_fraction_per_match, probability_rule = params
    
    # Asegurar que los parámetros estén dentro de los límites
    if not (0 < risk_factor <= 1):
        return np.inf
    if not (0 < max_daily_bet_fraction <= 1):
        return np.inf
    if not (0 < max_bet_fraction_per_match <= 1):
        return np.inf
    if not (0 < probability_rule <= 1):
        return np.inf
    
    bankroll = initial_capital
    dates = resultado['Date'].unique()
    
    for date in dates:
        day_matches = resultado[resultado['Date'] == date]
        daily_bet_amount = 0
        daily_max_bet = bankroll * max_daily_bet_fraction
        
        for idx, match in day_matches.iterrows():
            if match["winner_prediction"] == "pl1":
                p1_win_prob = match['probability']
            else:
                p1_win_prob = 1 - match['probability']
                
            p1_loss_prob = 1 - p1_win_prob
            odds_p1 = match['pl1_bet']
            b1 = odds_p1 - 1
            f1 = (b1 * p1_win_prob - p1_loss_prob) / b1
            f1 = max(f1, 0) * risk_factor
            f1 = min(f1, 1)
            
            # Cálculo para el Jugador 2
            p2_win_prob = 1 - p1_win_prob
            p2_loss_prob = 1 - p2_win_prob
            odds_p2 = match['pl2_bet']
            b2 = odds_p2 - 1
            f2 = (b2 * p2_win_prob - p2_loss_prob) / b2
            f2 = max(f2, 0) * risk_factor
            f2 = min(f2, 1)
            
            # Decidir por qué jugador apostar
            if f1 > f2 and f1 > 0:
                f = f1
                odds = odds_p1
                player_bet_on = 'pl1'
                win_prob = p1_win_prob
            elif f2 > f1 and f2 > 0:
                f = f2
                odds = odds_p2
                player_bet_on = 'pl2'
                win_prob = p2_win_prob
            else:
                continue  # No apostar si no hay valor positivo de Kelly
            
            if win_prob <= probability_rule:
                continue 
            
            max_bet_amount_per_match = bankroll * max_bet_fraction_per_match
            bet_amount = f * bankroll
            bet_amount = min(bet_amount, max_bet_amount_per_match)
            
            # Asegurar que no se exceda el máximo diario
            if daily_bet_amount + bet_amount > daily_max_bet:
                bet_amount = daily_max_bet - daily_bet_amount
                if bet_amount <= 0:
                    continue
                f = bet_amount / bankroll  # Recalcular fracción de Kelly
            
            daily_bet_amount += bet_amount
            
            # Actualizar capital basado en los resultados
            actual_winner = match['ActualWinner']  # Debes tener esta columna en tu DataFrame
            if actual_winner == player_bet_on:
                payout = bet_amount * odds
                profit = payout - bet_amount
                bankroll += profit
            else:
                bankroll -= bet_amount
            
            if bankroll <= 0:
                return np.inf  # Quiebra, resultado no deseado
    
    # Devolver el capital final negativo para minimizar
    return -bankroll

# Función objetivo para Optuna
def objective(trial):
    risk_factor = trial.suggest_uniform('risk_factor', 0.1, 0.98)
    max_daily_bet_fraction = trial.suggest_uniform('max_daily_bet_fraction', 0.05, 0.90)
    max_bet_fraction_per_match = trial.suggest_uniform('max_bet_fraction_per_match', 0.05, 0.50)
    probability_rule = trial.suggest_uniform('probability_rule', 0.20, 0.97)
    
    params = [risk_factor, max_daily_bet_fraction, max_bet_fraction_per_match, probability_rule]
    final_capital = simulate_betting_strategy(params, resultado)
    
    return final_capital

# Crear estudio y optimizar
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=3000)

# Mostrar los mejores parámetros
print("Mejores parámetros encontrados:")
trial = study.best_trial

print(f"  Risk Factor: {trial.params['risk_factor']:.4f}")
print(f"  Max Daily Bet Fraction: {trial.params['max_daily_bet_fraction']:.4f}")
print(f"  Max Bet Fraction per Match: {trial.params['max_bet_fraction_per_match']:.4f}")
print(f"  Probability Rule: {trial.params['probability_rule']:.4f}")
print(f"  Capital Final: {-trial.value:.2f} USD")
# Out:
# [I 2024-10-02 19:39:25,692] A new study created in memory with name: no-name-10a8db8c-2791-4d76-95f5-cd724d757ab8
# C:\Users\Julián Pérez\AppData\Local\Temp\ipykernel_10416\3449184236.py:96: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   risk_factor = trial.suggest_uniform('risk_factor', 0.1, 0.98)
# C:\Users\Julián Pérez\AppData\Local\Temp\ipykernel_10416\3449184236.py:97: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_daily_bet_fraction = trial.suggest_uniform('max_daily_bet_fraction', 0.05, 0.90)
# C:\Users\Julián Pérez\AppData\Local\Temp\ipykernel_10416\3449184236.py:98: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_bet_fraction_per_match = trial.suggest_uniform('max_bet_fraction_per_match', 0.05, 0.50)
# C:\Users\Julián Pérez\AppData\Local\Temp\ipykernel_10416\3449184236.py:99: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   probability_rule = trial.suggest_uniform('probability_rule', 0.20, 0.97)
# [I 2024-10-02 19:39:25,734] Trial 0 finished with value: -69.1058656410765 and parameters: {'risk_factor': 0.94870486932565, 'max_daily_bet_fraction': 0.10884763703477224, 'max_bet_fraction_per_match': 0.402614233285059, 'probability_rule': 0.2974352089399024}. Best is trial 0 with value: -69.1058656410765.
# [I 2024-10-02 19:39:25,772] Trial 1 finished with value: -1.920287505753906 and parameters: {'risk_factor': 0.9458430656553517, 'max_daily_bet_fraction': 0.46426671222833166, 'max_bet_fraction_per_match': 0.36198230868548714, 'probability_rule': 0.5944608354123188}. Best is trial 0 with value: -69.1058656410765.
# [I 2024-10-02 19:39:25,810] Trial 2 finished with value: -18.845143537059208 and parameters: {'risk_factor': 0.38059905563893104, 'max_daily_bet_fraction': 0.23336079390923337, 'max_bet_fraction_per_match': 0.326264933618878, 'probability_rule': 0.49666436321695456}. Best is trial 0 with value: -69.1058656410765.
# [I 2024-10-02 19:39:25,847] Trial 3 finished with value: -1.4500033252349658 and parameters: {'risk_factor': 0.5364627154856622, 'max_daily_bet_fraction': 0.4893888842705572, 'max_bet_fraction_per_match': 0.3244510257012155, 'probability_rule': 0.6881598801084745}. Best is trial 0 with value: -69.1058656410765.
# [I 2024-10-02 19:39:25,882] Trial 4 finished with value: -25.965505018950203 and parameters: {'risk_factor': 0.37513678635150005, 'max_daily_bet_fraction': 0.172995069665129, 'max_bet_fraction_per_match': 0.15737262345806766, 'probability_rule': 0.523848507639283}. Best is trial 0 with value: -69.1058656410765.
# [I 2024-10-02 19:39:25,917] Trial 5 finished with value: -93.10615865346686 and parameters: {'risk_factor': 0.8353789462200173, 'max_daily_bet_fraction': 0.055134608658471196, 'max_bet_fraction_per_match': 0.31442414489465853, 'probability_rule': 0.3822744862889522}. Best is trial 5 with value: -93.10615865346686.
# [I 2024-10-02 19:39:25,953] Trial 6 finished with value: -46.75118067329033 and parameters: {'risk_factor': 0.5132249181166105, 'max_daily_bet_fraction': 0.0966004984480142, 'max_bet_fraction_per_match': 0.2688213375396779, 'probability_rule': 0.7371468124086422}. Best is trial 5 with value: -93.10615865346686.
# [I 2024-10-02 19:39:25,992] Trial 7 finished with value: -82.08527401314451 and parameters: {'risk_factor': 0.32117126521998274, 'max_daily_bet_fraction': 0.20264131367185706, 'max_bet_fraction_per_match': 0.30151611006706486, 'probability_rule': 0.9167567823803424}. Best is trial 5 with value: -93.10615865346686.
# [I 2024-10-02 19:39:26,030] Trial 8 finished with value: -9.69332683989787 and parameters: {'risk_factor': 0.24104886456399832, 'max_daily_bet_fraction': 0.27918165967762315, 'max_bet_fraction_per_match': 0.24446847253110432, 'probability_rule': 0.5475424160749298}. Best is trial 5 with value: -93.10615865346686.
# [I 2024-10-02 19:39:26,067] Trial 9 finished with value: -0.04385903710636818 and parameters: {'risk_factor': 0.5657172524103317, 'max_daily_bet_fraction': 0.8005038188388821, 'max_bet_fraction_per_match': 0.4517786863564465, 'probability_rule': 0.40212976100034836}. Best is trial 5 with value: -93.10615865346686.
# [I 2024-10-02 19:39:26,117] Trial 10 finished with value: -0.04626341157297558 and parameters: {'risk_factor': 0.75238249303103, 'max_daily_bet_fraction': 0.8879097134719848, 'max_bet_fraction_per_match': 0.13658120876488042, 'probability_rule': 0.2549092234976239}. Best is trial 5 with value: -93.10615865346686.
# [I 2024-10-02 19:39:26,165] Trial 11 finished with value: -87.90612146326112 and parameters: {'risk_factor': 0.19448806447448008, 'max_daily_bet_fraction': 0.3552841345082941, 'max_bet_fraction_per_match': 0.20401210216235305, 'probability_rule': 0.9030249561474258}. Best is trial 5 with value: -93.10615865346686.
# [I 2024-10-02 19:39:26,213] Trial 12 finished with value: -99.61816000131093 and parameters: {'risk_factor': 0.10539916016238077, 'max_daily_bet_fraction': 0.42728051073085344, 'max_bet_fraction_per_match': 0.07664313663367214, 'probability_rule': 0.9466883712555227}. Best is trial 12 with value: -99.61816000131093.
# [I 2024-10-02 19:39:26,263] Trial 13 finished with value: -8.728629357252657 and parameters: {'risk_factor': 0.7475848566303772, 'max_daily_bet_fraction': 0.6532514453806065, 'max_bet_fraction_per_match': 0.10779580311384407, 'probability_rule': 0.7787544753313018}. Best is trial 12 with value: -99.61816000131093.
# [I 2024-10-02 19:39:26,311] Trial 14 finished with value: -17.616802081712414 and parameters: {'risk_factor': 0.10473912198642504, 'max_daily_bet_fraction': 0.6011837947170422, 'max_bet_fraction_per_match': 0.05244879470257227, 'probability_rule': 0.3492834631795568}. Best is trial 12 with value: -99.61816000131093.
# [I 2024-10-02 19:39:26,360] Trial 15 finished with value: -4.171008923598832 and parameters: {'risk_factor': 0.7519657273126645, 'max_daily_bet_fraction': 0.39038264119591803, 'max_bet_fraction_per_match': 0.21776521290717032, 'probability_rule': 0.4220068439043938}. Best is trial 12 with value: -99.61816000131093.
# [I 2024-10-02 19:39:26,408] Trial 16 finished with value: -101.85726433344408 and parameters: {'risk_factor': 0.6384554403412286, 'max_daily_bet_fraction': 0.6424764812709575, 'max_bet_fraction_per_match': 0.0683845093601034, 'probability_rule': 0.9691372136516133}. Best is trial 16 with value: -101.85726433344408.
# [I 2024-10-02 19:39:26,456] Trial 17 finished with value: -101.48419152668211 and parameters: {'risk_factor': 0.6400239847481592, 'max_daily_bet_fraction': 0.5933038141119629, 'max_bet_fraction_per_match': 0.05328385279500182, 'probability_rule': 0.9688811696974132}. Best is trial 16 with value: -101.85726433344408.
# [I 2024-10-02 19:39:26,503] Trial 18 finished with value: -17.973477253613193 and parameters: {'risk_factor': 0.6409888559511117, 'max_daily_bet_fraction': 0.6490769527679822, 'max_bet_fraction_per_match': 0.16793226955445587, 'probability_rule': 0.8276092670287037}. Best is trial 16 with value: -101.85726433344408.
# [I 2024-10-02 19:39:26,550] Trial 19 finished with value: -46.022944082967825 and parameters: {'risk_factor': 0.6385114801700769, 'max_daily_bet_fraction': 0.7468352654720588, 'max_bet_fraction_per_match': 0.1087313634008672, 'probability_rule': 0.8617025700329122}. Best is trial 16 with value: -101.85726433344408.
# [I 2024-10-02 19:39:26,597] Trial 20 finished with value: -101.49578444004982 and parameters: {'risk_factor': 0.4570501162975028, 'max_daily_bet_fraction': 0.548815145713625, 'max_bet_fraction_per_match': 0.05592139617634884, 'probability_rule': 0.9675771794990562}. Best is trial 16 with value: -101.85726433344408.
# [I 2024-10-02 19:39:26,644] Trial 21 finished with value: -91.75536375828531 and parameters: {'risk_factor': 0.45313341985873923, 'max_daily_bet_fraction': 0.5610145979713066, 'max_bet_fraction_per_match': 0.05295355189440283, 'probability_rule': 0.9406799544947565}. Best is trial 16 with value: -101.85726433344408.
# [I 2024-10-02 19:39:26,691] Trial 22 finished with value: -37.71373713974156 and parameters: {'risk_factor': 0.6162067633428594, 'max_daily_bet_fraction': 0.5529981137338752, 'max_bet_fraction_per_match': 0.09314697595834298, 'probability_rule': 0.8423319204650545}. Best is trial 16 with value: -101.85726433344408.
# [I 2024-10-02 19:39:26,739] Trial 23 finished with value: -106.46656825962083 and parameters: {'risk_factor': 0.452919592257052, 'max_daily_bet_fraction': 0.695990575421209, 'max_bet_fraction_per_match': 0.1334675205390762, 'probability_rule': 0.9611149086291991}. Best is trial 23 with value: -106.46656825962083.
# [I 2024-10-02 19:39:26,786] Trial 24 finished with value: -0.8405355896313041 and parameters: {'risk_factor': 0.44816104204514107, 'max_daily_bet_fraction': 0.7383452715501935, 'max_bet_fraction_per_match': 0.13412582747604657, 'probability_rule': 0.6483289506361165}. Best is trial 23 with value: -106.46656825962083.
# [I 2024-10-02 19:39
. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,459] Trial 38 finished with value: -57.83738480998326 and parameters: {'risk_factor': 0.802049410211312, 'max_daily_bet_fraction': 0.7916940870167108, 'max_bet_fraction_per_match': 0.43755863691625946, 'probability_rule': 0.9199086791161905}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,507] Trial 39 finished with value: -1.2575275279079392 and parameters: {'risk_factor': 0.8798733123305305, 'max_daily_bet_fraction': 0.5093004482848856, 'max_bet_fraction_per_match': 0.26737159920506226, 'probability_rule': 0.20721144685167792}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,557] Trial 40 finished with value: -0.1851377950352692 and parameters: {'risk_factor': 0.3913369323541446, 'max_daily_bet_fraction': 0.8305384497971038, 'max_bet_fraction_per_match': 0.3394558360979283, 'probability_rule': 0.47660387652227443}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,608] Trial 41 finished with value: -89.70315366736126 and parameters: {'risk_factor': 0.591759148105103, 'max_daily_bet_fraction': 0.6731781826609202, 'max_bet_fraction_per_match': 0.07700063807075833, 'probability_rule': 0.9464424036766717}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,662] Trial 42 finished with value: -64.78740384657222 and parameters: {'risk_factor': 0.700235255568655, 'max_daily_bet_fraction': 0.6265538093334646, 'max_bet_fraction_per_match': 0.1218401784258505, 'probability_rule': 0.8840621623547826}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,715] Trial 43 finished with value: -103.81929058530824 and parameters: {'risk_factor': 0.5098534104822182, 'max_daily_bet_fraction': 0.7483686810621895, 'max_bet_fraction_per_match': 0.073355447113927, 'probability_rule': 0.9600478348916546}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,769] Trial 44 finished with value: -80.84067056566354 and parameters: {'risk_factor': 0.524192091359704, 'max_daily_bet_fraction': 0.7735153848389631, 'max_bet_fraction_per_match': 0.15097482808714052, 'probability_rule': 0.915390670186864}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,817] Trial 45 finished with value: -29.851998843339747 and parameters: {'risk_factor': 0.3615980989184131, 'max_daily_bet_fraction': 0.8634101341049631, 'max_bet_fraction_per_match': 0.4149888766368192, 'probability_rule': 0.8218382275572719}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,866] Trial 46 finished with value: -0.12390875122040355 and parameters: {'risk_factor': 0.5551351094123507, 'max_daily_bet_fraction': 0.7565368487334642, 'max_bet_fraction_per_match': 0.29125434778941006, 'probability_rule': 0.5911069444807845}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,918] Trial 47 finished with value: -1.5055326598020033 and parameters: {'risk_factor': 0.9239844610425696, 'max_daily_bet_fraction': 0.7019534871164812, 'max_bet_fraction_per_match': 0.11253629853359942, 'probability_rule': 0.7125323857367867}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:27,967] Trial 48 finished with value: -95.23403025045317 and parameters: {'risk_factor': 0.49377210310730757, 'max_daily_bet_fraction': 0.4536482017073532, 'max_bet_fraction_per_match': 0.49563661903531675, 'probability_rule': 0.9356744141897366}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:28,017] Trial 49 finished with value: -50.3642135937473 and parameters: {'risk_factor': 0.41457354623226533, 'max_daily_bet_fraction': 0.8145734184961236, 'max_bet_fraction_per_match': 0.1726633380659967, 'probability_rule': 0.8560690163293876}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:28,066] Trial 50 finished with value: -101.99897705507667 and parameters: {'risk_factor': 0.3292101717149467, 'max_daily_bet_fraction': 0.7310462029893252, 'max_bet_fraction_per_match': 0.0809771807790581, 'probability_rule': 0.9699487776798034}. Best is trial 34 with value: -111.38088267686649.
# [I 2024-10-02 19:39:28
# [I 2024-10-02 19:39:29,402] Trial 77 finished with value: -63.66905424778889 and parameters: {'risk_factor': 0.6768243816087911, 'max_daily_bet_fraction': 0.5287192338590639, 'max_bet_fraction_per_match': 0.38454144861424083, 'probability_rule': 0.9195994113274727}. Best is trial 74 with value: -115.70405074801133.
# [I 2024-10-02 19:39:29,449] Trial 78 finished with value: -55.26651426479268 and parameters: {'risk_factor': 0.7862763489511854, 'max_daily_bet_fraction': 0.634362308256322, 'max_bet_fraction_per_match': 0.24955996467187733, 'probability_rule': 0.8779768134257536}. Best is trial 74 with value: -115.70405074801133.
# [I 2024-10-02 19:39:29,497] Trial 79 finished with value: -116.23307812326976 and parameters: {'risk_factor': 0.9093190459746241, 'max_daily_bet_fraction': 0.5451809586208558, 'max_bet_fraction_per_match': 0.30146266005353856, 'probability_rule': 0.9523715451274094}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,546] Trial 80 finished with value: -1.5211267405334894 and parameters: {'risk_factor': 0.9104234808707905, 'max_daily_bet_fraction': 0.47339772807946234, 'max_bet_fraction_per_match': 0.34896484494687624, 'probability_rule': 0.47140923161972925}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,604] Trial 81 finished with value: -85.6363979006189 and parameters: {'risk_factor': 0.9639721389692172, 'max_daily_bet_fraction': 0.5323103423589077, 'max_bet_fraction_per_match': 0.2870539786836577, 'probability_rule': 0.9446203503346835}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,657] Trial 82 finished with value: -113.71341263470704 and parameters: {'risk_factor': 0.8549924417151816, 'max_daily_bet_fraction': 0.5935373495988979, 'max_bet_fraction_per_match': 0.2662925608010194, 'probability_rule': 0.9534692266967919}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,705] Trial 83 finished with value: -67.45937489072665 and parameters: {'risk_factor': 0.8343343986278127, 'max_daily_bet_fraction': 0.5974008563935458, 'max_bet_fraction_per_match': 0.30964240094106643, 'probability_rule': 0.9069249470650131}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,753] Trial 84 finished with value: -88.0628051253799 and parameters: {'risk_factor': 0.8628466077154364, 'max_daily_bet_fraction': 0.5692381133461024, 'max_bet_fraction_per_match': 0.2650360545471897, 'probability_rule': 0.927528039610297}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,802] Trial 85 finished with value: -0.7603033272697581 and parameters: {'risk_factor': 0.9043559778896317, 'max_daily_bet_fraction': 0.5405867932876973, 'max_bet_fraction_per_match': 0.30252571617871615, 'probability_rule': 0.6358705501625265}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,850] Trial 86 finished with value: -112.67812531692795 and parameters: {'risk_factor': 0.7643353538998514, 'max_daily_bet_fraction': 0.45190566097801277, 'max_bet_fraction_per_match': 0.3235748897625316, 'probability_rule': 0.9541956483913172}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,899] Trial 87 finished with value: -90.47815876589732 and parameters: {'risk_factor': 0.7753271628791234, 'max_daily_bet_fraction': 0.4876088470796621, 'max_bet_fraction_per_match': 0.37385745025005895, 'probability_rule': 0.9281470023290326}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,947] Trial 88 finished with value: -22.001530566420662 and parameters: {'risk_factor': 0.8249131553781935, 'max_daily_bet_fraction': 0.6053937429541661, 'max_bet_fraction_per_match': 0.32965554658057744, 'probability_rule': 0.8594063925730955}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:29,996] Trial 89 finished with value: -57.548733184543195 and parameters: {'risk_factor': 0.8665749797941528, 'max_daily_bet_fraction': 0.4452497253321821, 'max_bet_fraction_per_match': 0.29544814815062204, 'probability_rule': 0.8983042259542919}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,047] Trial 90 finished with value: -113.05030653862009 and parameters: {'risk_factor': 0.7453460103226517, 'max_daily_bet_fraction': 0.5540113163556684, 'max_bet_fraction_per_match': 0.2821827744337015, 'probability_rule': 0.9527584287244489}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,098] Trial 91 finished with value: -110.00805855640385 and parameters: {'risk_factor': 0.7412929981202884, 'max_daily_bet_fraction': 0.41875547429214743, 'max_bet_fraction_per_match': 0.23687779182862176, 'probability_rule': 0.9567932252821366}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,148] Trial 92 finished with value: -105.81429278660116 and parameters: {'risk_factor': 0.744598839398013, 'max_daily_bet_fraction': 0.3987921857842558, 'max_bet_fraction_per_match': 0.25534471995670527, 'probability_rule': 0.9697492173545165}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,200] Trial 93 finished with value: -89.73575470789555 and parameters: {'risk_factor': 0.8035396391754706, 'max_daily_bet_fraction': 0.42941948817435716, 'max_bet_fraction_per_match': 0.23424321816912036, 'probability_rule': 0.9484324614334511}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,251] Trial 94 finished with value: -87.16146853434671 and parameters: {'risk_factor': 0.8446337097287526, 'max_daily_bet_fraction': 0.3637741376926315, 'max_bet_fraction_per_match': 0.2782659307713289, 'probability_rule': 0.9342801914279283}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,299] Trial 95 finished with value: -71.90578045746551 and parameters: {'risk_factor': 0.7485721949202876, 'max_daily_bet_fraction': 0.5201677244476458, 'max_bet_fraction_per_match': 0.26192800127182886, 'probability_rule': 0.9126900548026115}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,352] Trial 96 finished with value: -37.82168310101832 and parameters: {'risk_factor': 0.6610273689509774, 'max_daily_bet_fraction': 0.5520541486785314, 'max_bet_fraction_per_match': 0.32201404887875673, 'probability_rule': 0.8705652650744982}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,402] Trial 97 finished with value: -86.96745734738408 and parameters: {'risk_factor': 0.9443360145688007, 'max_daily_bet_fraction': 0.502260507372628, 'max_bet_fraction_per_match': 0.2385647848673422, 'probability_rule': 0.9486893681211465}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,450] Trial 98 finished with value: -44.91804955239746 and parameters: {'risk_factor': 0.890665484170639, 'max_daily_bet_fraction': 0.4203579729029172, 'max_bet_fraction_per_match': 0.2860922522759153, 'probability_rule': 0.8889170463061975}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,502] Trial 99 finished with value: -5.170769756027945 and parameters: {'risk_factor': 0.7912207472518482, 'max_daily_bet_fraction': 0.5698110671342514, 'max_bet_fraction_per_match': 0.2244184964618187, 'probability_rule': 0.8113372287130777}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,556] Trial 100 finished with value: -62.00010693867274 and parameters: {'risk_factor': 0.7702069065820353, 'max_daily_bet_fraction': 0.4632108059605129, 'max_bet_fraction_per_match': 0.3374433929864779, 'probability_rule': 0.9176297472175046}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,606] Trial 101 finished with value: -105.87411403698526 and parameters: {'risk_factor': 0.7426925314889239, 'max_daily_bet_fraction': 0.38846348553887516, 'max_bet_fraction_per_match': 0.2613405954299801, 'probability_rule': 0.969726134516745}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,659] Trial 102 finished with value: -111.85136662789472 and parameters: {'risk_factor': 0.919706155225712, 'max_daily_bet_fraction': 0.3634021289120306, 'max_bet_fraction_per_match': 0.2747578006892331, 'probability_rule': 0.9534124911062072}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,709] Trial 103 finished with value: -110.81354309571375 and parameters: {'risk_factor': 0.7301753953165563, 'max_daily_bet_fraction': 0.31532199759584495, 'max_bet_fraction_per_match': 0.2776813431232456, 'probability_rule': 0.9535409514470783}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,761] Trial 104 finished with value: -90.2295400705007 and parameters: {'risk_factor': 0.7245448664677289, 'max_daily_bet_fraction': 0.35620834630853976, 'max_bet_fraction_per_match': 0.30068986011195037, 'probability_rule': 0.9373898804170058}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,812] Trial 105 finished with value: -86.72095576154301 and parameters: {'risk_factor': 0.9175792402666804, 'max_daily_bet_fraction': 0.3104051909801518, 'max_bet_fraction_per_match': 0.2706150844550598, 'probability_rule': 0.9490345091616781}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,862] Trial 106 finished with value: -62.67821913567241 and parameters: {'risk_factor': 0.8215224431239597, 'max_daily_bet_fraction': 0.31943795287516197, 'max_bet_fraction_per_match': 0.45488301608001425, 'probability_rule': 0.9111589827411718}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,911] Trial 107 finished with value: -109.56304882070629 and parameters: {'risk_factor': 0.9790337398403768, 'max_daily_bet_fraction': 0.21593963690351242, 'max_bet_fraction_per_match': 0.281550058000511, 'probability_rule': 0.9548906303739525}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:30,961] Trial 108 finished with value: -82.63985635359295 and parameters: {'risk_factor': 0.964336660530821, 'max_daily_bet_fraction': 0.25337600399746885, 'max_bet_fraction_per_match': 0.2775220159067423, 'probability_rule': 0.9289634346893285}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31,010] Trial 109 finished with value: -54.953991246835194 and parameters: {'risk_factor': 0.9297434758725962, 'max_daily_bet_fraction': 0.21129506764669714, 'max_bet_fraction_per_match': 0.32032767523214994, 'probability_rule': 0.8960245549419328}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31,058] Trial 110 finished with value: -111.87038180605424 and parameters: {'risk_factor': 0.8832244562829152, 'max_daily_bet_fraction': 0.2951680997903873, 'max_bet_fraction_per_match': 0.3038019619643079, 'probability_rule': 0.9550698742792489}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31,108] Trial 111 finished with value: -110.62855805994477 and parameters: {'risk_factor': 0.8781206253572914, 'max_daily_bet_fraction': 0.2952747673022752, 'max_bet_fraction_per_match': 0.30821696493031986, 'probability_rule': 0.9558872351097685}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31,157] Trial 112 finished with value: -85.93198371474445 and parameters: {'risk_factor': 0.877076713430004, 'max_daily_bet_fraction': 0.29547102017942184, 'max_bet_fraction_per_match': 0.3091155073112912, 'probability_rule': 0.9344235931037698}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31,205] Trial 113 finished with value: -110.92422930338668 and parameters: {'risk_factor': 0.8854413052821781, 'max_daily_bet_fraction': 0.33832638408030047, 'max_bet_fraction_per_match': 0.29681565273483423, 'probability_rule': 0.9552471978798431}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31,254] Trial 114 finished with value: -85.79347494413057 and parameters: {'risk_factor': 0.9035415614070246, 'max_daily_bet_fraction': 0.3413211327781932, 'max_bet_fraction_per_match': 0.2978471035444305, 'probability_rule': 0.9243872725008258}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31,304] Trial 115 finished with value: -112.91716963955976 and parameters: {'risk_factor': 0.8765411316892219, 'max_daily_bet_fraction': 0.26965495450585897, 'max_bet_fraction_per_match': 0.3477628468050914, 'probability_rule': 0.9521659657321074}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31,354] Trial 116 finished with value: -64.16855724465344 and parameters: {'risk_factor': 0.8817994908264576, 'max_daily_bet_fraction': 0.2757229352427641, 'max_bet_fraction_per_match': 0.36008714303746214, 'probability_rule': 0.9085270019154522}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:31
. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,046] Trial 130 finished with value: -112.97457737223621 and parameters: {'risk_factor': 0.891927343800244, 'max_daily_bet_fraction': 0.48786171842949705, 'max_bet_fraction_per_match': 0.27433723057732395, 'probability_rule': 0.9533297854355869}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,095] Trial 131 finished with value: -114.80017447356991 and parameters: {'risk_factor': 0.8899875644190309, 'max_daily_bet_fraction': 0.48161076930012786, 'max_bet_fraction_per_match': 0.2738692396718342, 'probability_rule': 0.9518129720756429}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,145] Trial 132 finished with value: -86.06381756711683 and parameters: {'risk_factor': 0.9113754426173551, 'max_daily_bet_fraction': 0.4844163564515135, 'max_bet_fraction_per_match': 0.2575575036570992, 'probability_rule': 0.9402004122331364}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,194] Trial 133 finished with value: -112.4033641277987 and parameters: {'risk_factor': 0.894750795040744, 'max_daily_bet_fraction': 0.4398947458845804, 'max_bet_fraction_per_match': 0.27466892359185885, 'probability_rule': 0.9543877656313597}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,243] Trial 134 finished with value: -86.00924647776903 and parameters: {'risk_factor': 0.8896948648056442, 'max_daily_bet_fraction': 0.4397390160736422, 'max_bet_fraction_per_match': 0.24568626559802628, 'probability_rule': 0.9241423864305655}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,292] Trial 135 finished with value: -40.981673307934756 and parameters: {'risk_factor': 0.9375952442092997, 'max_daily_bet_fraction': 0.4670357148625653, 'max_bet_fraction_per_match': 0.49990957681911286, 'probability_rule': 0.9004294714758712}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,340] Trial 136 finished with value: -106.56381333495534 and parameters: {'risk_factor': 0.8577782273245492, 'max_daily_bet_fraction': 0.5215444647926798, 'max_bet_fraction_per_match': 0.2736398976094863, 'probability_rule': 0.9696494962720585}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,389] Trial 137 finished with value: -86.3081633290829 and parameters: {'risk_factor': 0.8969911362938815, 'max_daily_bet_fraction': 0.41072755920034226, 'max_bet_fraction_per_match': 0.28880501583370827, 'probability_rule': 0.9380232616828031}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,438] Trial 138 finished with value: -57.101935061393334 and parameters: {'risk_factor': 0.9201122612554048, 'max_daily_bet_fraction': 0.4897105518651365, 'max_bet_fraction_per_match': 0.37074420093755667, 'probability_rule': 0.9149976854122701}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,488] Trial 139 finished with value: -113.28811336216062 and parameters: {'risk_factor': 0.8699807204820679, 'max_daily_bet_fraction': 0.4507386899726661, 'max_bet_fraction_per_match': 0.32484675305839994, 'probability_rule': 0.9548414140329574}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,537] Trial 140 finished with value: -56.341282573520346 and parameters: {'risk_factor': 0.8660976248243311, 'max_daily_bet_fraction': 0.4434979600808486, 'max_bet_fraction_per_match': 0.32219342907798654, 'probability_rule': 0.8905756765424614}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,586] Trial 141 finished with value: -113.00690497892242 and parameters: {'risk_factor': 0.8961967365951579, 'max_daily_bet_fraction': 0.4584085792471687, 'max_bet_fraction_per_match': 0.292913663830951, 'probability_rule': 0.9527198136235763}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,635] Trial 142 finished with value: -2.5124644124845554 and parameters: {'risk_factor': 0.9561688408801611, 'max_daily_bet_fraction': 0.45842622808761935, 'max_bet_fraction_per_match': 0.42323854538812383, 'probability_rule': 0.3411770138933674}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,684] Trial 143 finished with value: -88.09385782758719 and parameters: {'risk_factor': 0.8435142813130092, 'max_daily_bet_fraction': 0.49825258678475864, 'max_bet_fraction_per_match': 0.26729851799264587, 'probability_rule': 0.9334369675456995}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,735] Trial 144 finished with value: -107.35650688977528 and parameters: {'risk_factor': 0.9073893066615601, 'max_daily_bet_fraction': 0.4308267789620275, 'max_bet_fraction_per_match': 0.3436540928142259, 'probability_rule': 0.9696148442981438}. Best is trial 79 with value: -116.23307812326976.
# [I 2024-10-02 19:39:32,785] Trial 145 finished with value: -85.88999644342304 and parameters: {'risk_factor': 0.935041982284618, 'max_daily_bet_fraction': 0.549704566527474, 'max_bet_fraction_per_match': 0.25362335560831845, 'probability_rule': 0.944481204906303}. Best is trial 79 with value: -116.23307812326976.
# ...
# [I 2024-10-02 19:43:02,004] Trial 2951 finished with value: -92.37154785678993 and parameters: {'risk_factor': 0.948279092140927, 'max_daily_bet_fraction': 0.887292062708153, 'max_bet_fraction_per_match': 0.48001865141355665, 'probability_rule': 0.946802225898674}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,148] Trial 2952 finished with value: -51.86010803803161 and parameters: {'risk_factor': 0.9653763486944877, 'max_daily_bet_fraction': 0.8838606519590214, 'max_bet_fraction_per_match': 0.487574153542467, 'probability_rule': 0.9085774740357283}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,252] Trial 2953 finished with value: -0.02907229568535165 and parameters: {'risk_factor': 0.939381522450716, 'max_daily_bet_fraction': 0.8745631972089709, 'max_bet_fraction_per_match': 0.4852534699788401, 'probability_rule': 0.7317568669142345}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,350] Trial 2954 finished with value: -89.83739819749238 and parameters: {'risk_factor': 0.9645359133086375, 'max_daily_bet_fraction': 0.8838921708118888, 'max_bet_fraction_per_match': 0.484326660294887, 'probability_rule': 0.9322285509499717}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,447] Trial 2955 finished with value: -118.18933929894962 and parameters: {'risk_factor': 0.9795857509409188, 'max_daily_bet_fraction': 0.8729135127988832, 'max_bet_fraction_per_match': 0.48498176022004486, 'probability_rule': 0.9575567455356436}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,548] Trial 2956 finished with value: -0.5402240360265921 and parameters: {'risk_factor': 0.9792959982123259, 'max_daily_bet_fraction': 0.8983102877989251, 'max_bet_fraction_per_match': 0.4833973855677369, 'probability_rule': 0.7954343596613983}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,646] Trial 2957 finished with value: -89.5902132355622 and parameters: {'risk_factor': 0.9794380225724607, 'max_daily_bet_fraction': 0.8860953611132979, 'max_bet_fraction_per_match': 0.4992851517927616, 'probability_rule': 0.943077984464356}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,746] Trial 2958 finished with value: -117.86611147306729 and parameters: {'risk_factor': 0.9475165891934066, 'max_daily_bet_fraction': 0.872956060717877, 'max_bet_fraction_per_match': 0.49271855181196766, 'probability_rule': 0.956349609887984}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,847] Trial 2959 finished with value: -90.5733501220122 and parameters: {'risk_factor': 0.9263838285127557, 'max_daily_bet_fraction': 0.8853497102794684, 'max_bet_fraction_per_match': 0.47733877291773374, 'probability_rule': 0.932224637018849}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:02,946] Trial 2960 finished with value: -109.96047919432257 and parameters: {'risk_factor': 0.9508249534693352, 'max_daily_bet_fraction': 0.8981912213793277, 'max_bet_fraction_per_match': 0.48035640982301325, 'probability_rule': 0.9698265820600221}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,047] Trial 2961 finished with value: -95.84746238767381 and parameters: {'risk_factor': 0.5629674759815644, 'max_daily_bet_fraction': 0.8991977278095796, 'max_bet_fraction_per_match': 0.48762593557861444, 'probability_rule': 0.9435065616612337}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,165] Trial 2962 finished with value: -49.2125756235194 and parameters: {'risk_factor': 0.97971677056387, 'max_daily_bet_fraction': 0.8726836156550773, 'max_bet_fraction_per_match': 0.47861834761736305, 'probability_rule': 0.9212303899266974}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,268] Trial 2963 finished with value: -118.13723224194655 and parameters: {'risk_factor': 0.9506900123998759, 'max_daily_bet_fraction': 0.8988058028303488, 'max_bet_fraction_per_match': 0.49412996234410583, 'probability_rule': 0.9561116432542313}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,366] Trial 2964 finished with value: -109.8474537600322 and parameters: {'risk_factor': 0.9351538855289205, 'max_daily_bet_fraction': 0.8998033705526339, 'max_bet_fraction_per_match': 0.47778449628031444, 'probability_rule': 0.9699824766739815}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,471] Trial 2965 finished with value: -47.100712864041526 and parameters: {'risk_factor': 0.965208044834165, 'max_daily_bet_fraction': 0.8722897071024904, 'max_bet_fraction_per_match': 0.49135883021618243, 'probability_rule': 0.8918143542629013}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,568] Trial 2966 finished with value: -91.83092397177452 and parameters: {'risk_factor': 0.8545997952471651, 'max_daily_bet_fraction': 0.8719839742915674, 'max_bet_fraction_per_match': 0.47643531966410596, 'probability_rule': 0.943385635989803}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,668] Trial 2967 finished with value: -90.90085241631753 and parameters: {'risk_factor': 0.9105840985654715, 'max_daily_bet_fraction': 0.8857897976621166, 'max_bet_fraction_per_match': 0.4829805040332786, 'probability_rule': 0.9314363937803375}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,766] Trial 2968 finished with value: -69.45094178811172 and parameters: {'risk_factor': 0.9492795817865837, 'max_daily_bet_fraction': 0.8716796880980413, 'max_bet_fraction_per_match': 0.2585220686023346, 'probability_rule': 0.9092479210336959}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,867] Trial 2969 finished with value: -117.81701581602266 and parameters: {'risk_factor': 0.9315985885786413, 'max_daily_bet_fraction': 0.8859196122102694, 'max_bet_fraction_per_match': 0.49107004292418416, 'probability_rule': 0.9558009868650047}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:03,976] Trial 2970 finished with value: -119.6155228752625 and parameters: {'risk_factor': 0.9799683866897091, 'max_daily_bet_fraction': 0.8718513771106715, 'max_bet_fraction_per_match': 0.47642388984065065, 'probability_rule': 0.9551723959826269}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,082] Trial 2971 finished with value: -89.636382476655 and parameters: {'risk_factor': 0.9791060743493875, 'max_daily_bet_fraction': 0.8986225810941602, 'max_bet_fraction_per_match': 0.4729161636632985, 'probability_rule': 0.9445185614272417}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,209] Trial 2972 finished with value: -118.09115899391094 and parameters: {'risk_factor': 0.9636938249890459, 'max_daily_bet_fraction': 0.8853048529207298, 'max_bet_fraction_per_match': 0.46724501088054143, 'probability_rule': 0.9578516658195941}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,325] Trial 2973 finished with value: -0.16661083560405948 and parameters: {'risk_factor': 0.9793450550787082, 'max_daily_bet_fraction': 0.885642643235229, 'max_bet_fraction_per_match': 0.4726375878116264, 'probability_rule': 0.7724374443967532}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,427] Trial 2974 finished with value: -89.43767290387362 and parameters: {'risk_factor': 0.9796223811773637, 'max_daily_bet_fraction': 0.8704397539286586, 'max_bet_fraction_per_match': 0.47567056438222555, 'probability_rule': 0.9318791689896662}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,531] Trial 2975 finished with value: -91.71049547896138 and parameters: {'risk_factor': 0.9791247865410759, 'max_daily_bet_fraction': 0.8730835603498008, 'max_bet_fraction_per_match': 0.4675639585489533, 'probability_rule': 0.9468084375875382}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,634] Trial 2976 finished with value: -109.9547614714684 and parameters: {'risk_factor': 0.9664121383591319, 'max_daily_bet_fraction': 0.8996638569081351, 'max_bet_fraction_per_match': 0.4719011605699269, 'probability_rule': 0.9698463619802045}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,736] Trial 2977 finished with value: -89.86579506623872 and parameters: {'risk_factor': 0.9626044164807015, 'max_daily_bet_fraction': 0.8857557068613797, 'max_bet_fraction_per_match': 0.4719568718350596, 'probability_rule': 0.9249872536303579}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,834] Trial 2978 finished with value: -118.24034625130886 and parameters: {'risk_factor': 0.965442436413332, 'max_daily_bet_fraction': 0.8985489888091053, 'max_bet_fraction_per_match': 0.47179733021261255, 'probability_rule': 0.9557702969130902}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:04,934] Trial 2979 finished with value: -104.40279903339945 and parameters: {'risk_factor': 0.9796097927335967, 'max_daily_bet_fraction': 0.8987704450747013, 'max_bet_fraction_per_match': 0.1693280992448873, 'probability_rule': 0.9697824189742112}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,034] Trial 2980 finished with value: -89.63564528036258 and parameters: {'risk_factor': 0.9793724826650593, 'max_daily_bet_fraction': 0.8995132577910746, 'max_bet_fraction_per_match': 0.4719593606370278, 'probability_rule': 0.9390673343988271}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,132] Trial 2981 finished with value: -91.71310681541897 and parameters: {'risk_factor': 0.9797710371872029, 'max_daily_bet_fraction': 0.8746014983204922, 'max_bet_fraction_per_match': 0.4693447641780544, 'probability_rule': 0.9475461406195718}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,231] Trial 2982 finished with value: -49.76640740414137 and parameters: {'risk_factor': 0.9626705759888501, 'max_daily_bet_fraction': 0.875260527506767, 'max_bet_fraction_per_match': 0.4742660850535912, 'probability_rule': 0.918220013991286}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,344] Trial 2983 finished with value: -89.92974086961966 and parameters: {'risk_factor': 0.9639437171652089, 'max_daily_bet_fraction': 0.8996239828347002, 'max_bet_fraction_per_match': 0.4687615586693192, 'probability_rule': 0.9341940052418078}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,441] Trial 2984 finished with value: -114.62372272885366 and parameters: {'risk_factor': 0.9649572504137941, 'max_daily_bet_fraction': 0.8650105929503806, 'max_bet_fraction_per_match': 0.2937445279987986, 'probability_rule': 0.9567351522966491}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,541] Trial 2985 finished with value: -52.41128315333914 and parameters: {'risk_factor': 0.9650706582516456, 'max_daily_bet_fraction': 0.8994640636715012, 'max_bet_fraction_per_match': 0.47659027325280734, 'probability_rule': 0.9098365227142902}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,637] Trial 2986 finished with value: -89.6324820108372 and parameters: {'risk_factor': 0.9788802948495928, 'max_daily_bet_fraction': 0.8993748000340066, 'max_bet_fraction_per_match': 0.4653128273961708, 'probability_rule': 0.9442526561240934}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,738] Trial 2987 finished with value: -119.22363850656225 and parameters: {'risk_factor': 0.9519237599204109, 'max_daily_bet_fraction': 0.869898750925544, 'max_bet_fraction_per_match': 0.46349082714799117, 'probability_rule': 0.9541585729077326}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,846] Trial 2988 finished with value: -89.75224001426405 and parameters: {'risk_factor': 0.964404967341014, 'max_daily_bet_fraction': 0.8722727664131593, 'max_bet_fraction_per_match': 0.48000609339811084, 'probability_rule': 0.9291549713989048}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:05,944] Trial 2989 finished with value: -118.03939880114937 and parameters: {'risk_factor': 0.9799162084731192, 'max_daily_bet_fraction': 0.8606945761015474, 'max_bet_fraction_per_match': 0.46657495226833734, 'probability_rule': 0.957157064423334}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,040] Trial 2990 finished with value: -37.893388547912934 and parameters: {'risk_factor': 0.9511052675412356, 'max_daily_bet_fraction': 0.899619719945476, 'max_bet_fraction_per_match': 0.4613407225831661, 'probability_rule': 0.8867857617063736}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,139] Trial 2991 finished with value: -109.9346977247538 and parameters: {'risk_factor': 0.9531004584315359, 'max_daily_bet_fraction': 0.8826067752792712, 'max_bet_fraction_per_match': 0.47679640424903047, 'probability_rule': 0.9698247801786222}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,239] Trial 2992 finished with value: -89.65489507827587 and parameters: {'risk_factor': 0.9644537941311245, 'max_daily_bet_fraction': 0.8625136073335343, 'max_bet_fraction_per_match': 0.4634327993145135, 'probability_rule': 0.9398666694635265}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,349] Trial 2993 finished with value: -55.173493632100055 and parameters: {'risk_factor': 0.9495788538539163, 'max_daily_bet_fraction': 0.8839324507782926, 'max_bet_fraction_per_match': 0.41755252813764865, 'probability_rule': 0.9180929921043613}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,450] Trial 2994 finished with value: -117.97107173851737 and parameters: {'risk_factor': 0.962820708927564, 'max_daily_bet_fraction': 0.8743350013258336, 'max_bet_fraction_per_match': 0.4623050447137721, 'probability_rule': 0.9564937724001122}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,552] Trial 2995 finished with value: -90.03513958740456 and parameters: {'risk_factor': 0.9445391822705397, 'max_daily_bet_fraction': 0.8589826398796558, 'max_bet_fraction_per_match': 0.47474991673884076, 'probability_rule': 0.934166592147534}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,653] Trial 2996 finished with value: -92.38115766574862 and parameters: {'risk_factor': 0.9627536070091384, 'max_daily_bet_fraction': 0.882341238190205, 'max_bet_fraction_per_match': 0.47142300486239225, 'probability_rule': 0.9459766893082272}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,750] Trial 2997 finished with value: -118.2807221730053 and parameters: {'risk_factor': 0.9792304216077717, 'max_daily_bet_fraction': 0.8851786380880624, 'max_bet_fraction_per_match': 0.4780172709663018, 'probability_rule': 0.9562490883614372}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,846] Trial 2998 finished with value: -104.59920331374825 and parameters: {'risk_factor': 0.43825286962762905, 'max_daily_bet_fraction': 0.8655382643944951, 'max_bet_fraction_per_match': 0.4255814674363527, 'probability_rule': 0.9698653274719753}. Best is trial 2939 with value: -122.1301023667724.
# [I 2024-10-02 19:43:06,948] Trial 2999 finished with value: -109.67489717558686 and parameters: {'risk_factor': 0.9427351725581972, 'max_daily_bet_fraction': 0.884622433305224, 'max_bet_fraction_per_match': 0.4578284948934912, 'probability_rule': 0.9699204411287365}. Best is trial 2939 with value: -122.1301023667724.
# Mejores parámetros encontrados:
#   Risk Factor: 0.9799
#   Max Daily Bet Fraction: 0.8996
#   Max Bet Fraction per Match: 0.4851
#   Probability Rule: 0.9522
#   Capital Final: 122.13 USD
